# %%
# %matplotlib inline

# %%
import json, glob, os, re
from pathlib import Path
import numpy as np

# %% [markdown]
# ## Quality Checks on Community Transcripts
#
# This notebook was used to perform quality checks and edits on fan-made community transcripts. The goal was to improve the alignment between those transcripts and the AssemblyAI speech-to-text output files, in order to assign more accuracte speaker tags to the AI transcripts.

# %%
"""
Support function loads and cleans up the .txt file's content
"""

def prep_ufs(s_num, e_num):
    """
    Extracts clean utterances from 
    Crazy for Friends fan-made transcripts
    """
    ufs_filepath = Path(
        "/home/mstlaure/Documents/Marie/neuromod/"
        "friends_annotations/annotation_results/"
        f"community_based/s{s_num}/friends_s0{s_num}e{e_num}_ufs.txt"
    )
    with open(ufs_filepath, 'r', encoding='utf-8') as f:
        ufs_transcript = f.read()

    ufs_processed = []
    for line in ufs_transcript.splitlines():
        # Remove all text inside parentheses and squared brackets (transcriber notes)
        line = re.sub(r'\s*\(.*?\)\s*', ' ', line)
        line = re.sub(r'\s*\[.*?\]\s*', ' ', line)
        line = line.strip()    
        # Only process lines that start with "Speaker:"
        if ":" in line:
            # Split line between speaker and utterance
            speaker, speech = line.strip().lower().split(":")
            sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?|\!)\s', speech)
            for s in sentences:
                if s.strip():
                    ufs_processed.append((speaker, s))

    return ufs_processed

# %%
s = "2"

tr_list = sorted(glob.glob(
    "/home/mstlaure/Documents/Marie/neuromod/"
    "friends_annotations/annotation_results/"
    f"community_based/s{s}/friends_s0{s}e*_ufs.txt"
    
))

# %%
"""
Idenfity loose text segments, e.g., dialog split on multiple lines that would become unassigned to a speaker in alignment scripts
"""

words_to_skip = [
    "Closing Credits and Bloopers",
    "Closing Credits", 
    "Commercial Break",
    "Opening Credits",
    "Ending Credits",
    "OPENING TITLES",
    "THE END",
    "Commercial",
    "End",
]
pattern = re.compile('|'.join(re.escape(word) for word in words_to_skip), re.IGNORECASE)

for tr in tr_list:
    with open(tr, 'r', encoding='utf-8') as f:
        ufs_transcript = f.read()
    print(os.path.basename(tr))
          
    for line in ufs_transcript.splitlines():
        # Remove all text inside parentheses and squared brackets (transcriber notes)
        line = re.sub(r'\s*\(.*?\)\s*', ' ', line)
        line = re.sub(r'\s*\[.*?\]\s*', ' ', line)
        line = pattern.sub('', line)
        line = line.strip()    # removes leading/trailing whitespace
        # Identify lines of dialog without a "Speaker:"
        if not ":" in line and line.strip():
            print(line)
    print("\n")
# Out:
# friends_s01e01_ufs.txt
#
#
# friends_s01e02_ufs.txt
#
#
# friends_s01e03_ufs.txt
# .
#
#
# friends_s01e04_ufs.txt
#
#
# friends_s01e05_ufs.txt
#
#
# friends_s01e06_ufs.txt
#
#
# friends_s01e07_ufs.txt
# .
#
#
# friends_s01e08_ufs.txt
#
#
# friends_s01e09_ufs.txt
#
#
# friends_s01e10_ufs.txt
#
#
# friends_s01e11_ufs.txt
#
#
# friends_s01e12_ufs.txt
#
#
# friends_s01e13_ufs.txt
#
#
# friends_s01e14_ufs.txt
#
#
# friends_s01e15_ufs.txt
#
#
# friends_s01e16_ufs.txt
#
#
# friends_s01e17_ufs.txt
#
#
# friends_s01e18_ufs.txt
#
#
# friends_s01e19_ufs.txt
#
#
# friends_s01e20_ufs.txt
#
#
# friends_s01e21_ufs.txt
#
#
# friends_s01e22_ufs.txt
#
#
# friends_s01e23_ufs.txt
#
#
# friends_s01e24_ufs.txt

# %%
"""
Identify lines with multiple ":" or ":" that don't indicate a speaker 

Also handle times (e.g., 6:30) to keep them from the transcripts


Compile lists of known speakers to ease mental load during manual checks
"""

known_names = {
    'chandler', 'joey', 'monica', 'phoebe', 'rachel', 'ross',
    'mr. geller', 'mrs. geller', 'woman', 'rachel and monica',
    'monica and phoebe', 'ross and rachel', 'gunther', 'melissa',
    'jake', 'tag', 'terry', 'the director', 'emily',
    'mr. bing', 'mrs. bing', 'phoebe and ross', 'richard',
    'all', 'fat monica', 'phoebe and rachel', 'man', 'woman',
    'joey and ross', 'julie', 'erin', 'female student', 'guy', 'janice',
    'joey’s date', 'male student', 'the colonel', 'the head librarian', 
    'the librarian', 'the waitress', 'ross and joey', 'ursula',
    'barry', 'bernice', 'carol', 'chandler and joey', 'susan',
    'joey and chandler', 'chandler and ross', 'ross and chandler', 
    'girls', 'guys',
}

for s in range(1, 8):
    tr_list = sorted(glob.glob(
        "/home/mstlaure/Documents/Marie/neuromod/"
        "friends_annotations/annotation_results/"
        f"community_based/s{s}/friends_s0{s}e*_ufs.txt"
        
    ))
    
    for tr in tr_list:
        with open(tr, 'r', encoding='utf-8') as f:
            ufs_transcript = f.read()
        print(os.path.basename(tr))
    
        speaker_list = []
        for line in ufs_transcript.splitlines():
            # Remove all text inside parentheses and squared brackets (transcriber notes)
            line = re.sub(r'\s*\(.*?\)\s*', ' ', line)
            line = re.sub(r'\s*\[.*?\]\s*', ' ', line)
            line = line.strip()        
            if ":" in line:
                # Split line between speaker and utterance
                line_splits = line.strip().lower().split(":")
                speaker = line_splits[0].strip()
                if speaker not in known_names:
                    speaker_list.append(speaker)
    
                speech = line_splits[1]
                if len(line_splits) > 2:  
                    for seg in line_splits[2:]:
                        speech += f":{seg}"
                #speaker, speech = line.strip().lower().split(":")
                #sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?|\!)\s', speech)
                #for s in sentences:
                #    if s.strip():
                #        ufs_processed.append((speaker, s))
    
                if len(line_splits) != 2:
                    print(line)
                    print(speech)
    
        
    
        print(np.unique(speaker_list))
        print("\n")
# Out:
# friends_s01e01_ufs.txt
# Monica: Oh really, so that hysterical phone call I got from a woman at sobbing 3:00 A.M., "I'll never have grandchildren, I'll never have grandchildren." was what?  A wrong number?
#  oh really, so that hysterical phone call i got from a woman at sobbing 3:00 a.m., "i'll never have grandchildren, i'll never have grandchildren." was what?  a wrong number?
# Monica: Oh God, is it 6:30?  Buzz him in!
#  oh god, is it 6:30?  buzz him in!
# ['customer' 'frannie' 'paul' 'phoebe, ross, chandler, and joey'
#  'priest on tv' 'waitress']
#
#
# friends_s01e02_ufs.txt
# ['chrissy on three’s company' 'dr. oberman' 'marsha' 'robbie']
#
#
# friends_s01e03_ufs.txt
# ['alan' 'everybody' 'lizzie' 'paula' 'the guys']
#
#
# friends_s01e04_ufs.txt
# ['joanne' 'kid' 'kiki' 'leslie' 'pizza guy' 'receptionist']
#
#
# friends_s01e05_ufs.txt
# ['angela' 'bob']
#
#
# friends_s01e06_ufs.txt
# ['all except joey' 'aurora' 'director' 'estelle']
#
#
# friends_s01e07_ufs.txt
# ['jill' 'monica, joey, and phoebe' 'mr. heckles' 'paolo']
#
#
# friends_s01e08_ufs.txt
# ['andrea' 'aunt lillian' 'lowell' 'nurse' 'shelley']
#
#
# friends_s01e09_ufs.txt
# ['girl']
#
#
# friends_s01e10_ufs.txt
# ['david' 'dick clark' 'everybody' 'fun bobby' 'max' 'sandy']
#
#
# friends_s01e11_ufs.txt
# ['coma guy' 'jay leno' 'paolo']
#
#
# friends_s01e12_ufs.txt
# Phoebe's Assistant: We've got a couple changes in your schedule. Your 4:00 herbal massage has been pushed back to 4:30 and Miss Somerfield canceled her 5:30 shiatsu.
#  we've got a couple changes in your schedule. your 4:00 herbal massage has been pushed back to 4:30 and miss somerfield canceled her 5:30 shiatsu.
# Phoebe's Assistant: Oh, here comes your 3:00. I don't mean to sound unprofessional, but, yum
#  oh, here comes your 3:00. i don't mean to sound unprofessional, but, yum
# Joey: Uh, it's 2:30 in the morning!
#  uh, it's 2:30 in the morning!
# ['carol and susan' 'customer' 'joey, chandler, and ross' 'paolo' 'paulo'
#  "phoebe's assistant" 'rachel and phoebe']
#
#
# friends_s01e13_ufs.txt
# ['mr. tribbiani' 'mrs. tribbiani' 'roger' 'ronni']
#
#
# friends_s01e14_ufs.txt
# ['fireman no. 1' 'fireman no. 2' 'fireman no. 3' 'kristin' 'lorraine'
#  'rachel and phoebe']
#
#
# friends_s01e15_ufs.txt
# ['announcer on tv' 'celia' 'helen' 'mrs. tedlock' 'steve']
#
#
# friends_s01e16_ufs.txt
# ['chandler & joey' 'fran' 'helen' 'jamie' 'monica and rachel'
#  'mr. douglas' 'mr.heckles' 'nina' 'rachel and chandler' 'ross and susan'
#  'soothing male voice' 'teacher']
#
#
# friends_s01e17_ufs.txt
# ['dr. mitchell' 'dr. rosen' 'nurse' "phoebe's friends" 'the whole party'
#  'waiting lady at the table']
#
#
# friends_s01e18_ufs.txt
# ['aunt iris']
#
#
# friends_s01e19_ufs.txt
# ['intercom' 'luisa' 'mr. heckles' 'phoebe and monica' 'woman no. 1'
#  'woman no. 2']
#
#
# friends_s01e20_ufs.txt
# ['bobby' 'danielle' 'mindy']
#
#
# friends_s01e21_ufs.txt
# ['actor' 'casting director no. 1' 'casting director no. 2' 'dr. baldhara'
#  'fake monica' 'public announcement' 'teacher' 'waiter']
#
#
# friends_s01e22_ufs.txt
# ['gerston' 'joey, chander, and ross' 'petrie' 'phoebe, joey, and ross'
#  'ross, rachel, and phoebe' 'santos' 'woman outside' 'young ethan']
#
#
# friends_s01e23_ufs.txt
# ['dr. franzblau' 'janitor' 'lydia' 'nurse' 'susan and ross']
#
#
# friends_s01e24_ufs.txt
# ['carl' 'flight attendant' 'intercom' 'melanie' 'ross and julie']
#
#
# friends_s02e01_ufs.txt
# Ross: Yeah, it's really 6:00 tomorrow night our time.
#  yeah, it's really 6:00 tomorrow night our time.
# ['frankie' 'paulo']
#
#
# friends_s02e02_ufs.txt
# ['annabelle' 'carol and susan' 'customer' 'hombre man' 'store guy']
#
#
# friends_s02e03_ufs.txt
# ['allison' 'mr. boyle' 'mr. heckles' 'mr. treeger']
#
#
# friends_s02e04_ufs.txt
# ['duncan' 'old woman' 'stranger']
#
#
# friends_s02e05_ufs.txt
# ['jade' 'machine' 'rachel, phoebe, and joey' 'ross and monica' 'steve'
#  'waiter' 'waitress' "woman's voice" 'young man']
#
#
# friends_s02e06_ufs.txt
# ['doctor' 'girl no. 1' 'girl no. 2' 'health services guy' 'kid'
#  'stephanie']
#
#
# friends_s02e07_ufs.txt
# Chandler: Monica, it's 6:30 in the morning. We're not working out, it's over.
#  monica, it's 6:30 in the morning. we're not working out, it's over.
# ['michael' 'waiter']
#
#
# friends_s02e08_ufs.txt
# ['chandler, joey, and ross' 'mr. ratstatter' 'phoebe and monica' 'radio']
#
#
# friends_s02e09_ufs.txt
# ['chandler, monica, and joey' 'mr. treeger' "phoebe's grandmother"]
#
#
# friends_s02e10_ufs.txt
# ['estelle' 'fun bobby' 'phoebe and chandler' 'russ' 'waiter']
#
#
# friends_s02e11_ufs.txt
# ['minister' 'mr. adelman' 'mrs. green' 'mrs. wallace'
#  'ross, chandler, and joey']
#
#
# friends_s02e12_ufs.txt
# ['commercial voiceover' 'erica' 'janitor' 'joey on tv' 'kid' 'kids'
#  'lipson' 'rob' 'security guard' 'trainer' 'tv doctor' 'waiter']
#
#
# friends_s02e13_ufs.txt
# ['director' "director's assistant" 'monica and rachel' 'susie' 'trainer'
#  'van damme']
#
#
# friends_s02e14_ufs.txt
# ['gail' 'interviewer' 'monica and ross' 'mr. and mrs. geller'
#  'rachel, monica, roy, and chip' 'roy']
#
#
# friends_s02e15_ufs.txt
# ['chandler, joey, and phoebe' 'delivery guy' 'dr. burke'
#  'rachel and phoebe']
#
#
# friends_s02e16_ufs.txt
# ['friend' 'joey’s co-star' 'tattoo artist']
#
#
# friends_s02e17_ufs.txt
# ['eddie' 'guy on intercom' 'lady in video' 'louie' 'producer']
#
#
# friends_s02e18_ufs.txt
# ['amber' 'delivery guy' 'dr. horton' 'dr. ramoray' 'eddie' 'intercom'
#  'tilly' 'writer']
#
#
# friends_s02e19_ufs.txt
# ['casting guy' 'eddie' 'estelle' 'mover']
#
#
# friends_s02e20_ufs.txt
# ['ben' 'carol and susan' 'ernie']
#
#
# friends_s02e21_ufs.txt
# ['big bully' 'frank' 'little bully' 'mrs. buffay']
#
#
# friends_s02e22_ufs.txt
# ['girl 1' 'girl’s voice' 'mr. green' 'mrs. green']
#
#
# friends_s02e23_ufs.txt
# ['jeannie' 'mr. douglas' 'phoebe and ryan' 'ryan' 'scott']
#
#
# friends_s02e24_ufs.txt
# Barry: And once again she is out of here. Okay who had 9:45? Um?
#  and once again she is out of here. okay who had 9:45? um?
# ['best man' 'mindy' 'mr. wineburg' 'mrs. wineburg' 'wedding planner']
#
#
# friends_s03e01_ufs.txt
# Video:April Twelve, Eighteen hundred, Sixty-One , 4:30 A.M. on Tuesday, the United States garrison at Fort Sumter was fired upon it is now under bombardment by....
# april twelve, eighteen hundred, sixty-one , 4:30 a.m. on tuesday, the united states garrison at fort sumter was fired upon it is now under bombardment by....
# ['video']
#
#
# friends_s03e02_ufs.txt
# Ross: Okay, hey, that's okay with me. Two down and I have exactly twelve minutes.... Wha, my watch stopped. My watch. Okay, see, the, the dinosaur tail isn't going around any more. What time is it? It's 7:33, I have seven minutes. I have seven minutes!!
#  okay, hey, that's okay with me. two down and i have exactly twelve minutes.... wha, my watch stopped. my watch. okay, see, the, the dinosaur tail isn't going around any more. what time is it? it's 7:33, i have seven minutes. i have seven minutes!!
# ['machine' 'michelle' "rachel's sister on the machine" 'sherman whitfield'
#  'the guys' 'whitfield' "woman's voice"]
#
#
# friends_s03e03_ufs.txt
# ['malcom']
#
#
# friends_s03e04_ufs.txt
# ['carol and susan' 'host' 'infomercial announcer' 'mike' 'young monica'
#  'young ross']
#
#
# friends_s03e05_ufs.txt
# ['frank' 'girl' 'isabella' 'jasmine' 'monica and rachel' 'phoebe and girl']
#
#
# friends_s03e06_ufs.txt
# ['eric' 'friend no. 1' 'friend no. 2' 'her friends' 'monica and rachel'
#  'mr. heckles' 'waitress']
#
#
# friends_s03e07_ufs.txt
# ['dr. green' 'jester' 'mattress king' 'student']
#
#
# friends_s03e08_ufs.txt
# ['ben' 'chandler and phoebe' 'monica and rachel']
#
#
# friends_s03e09_ufs.txt
# ['margha' 'monica and joey' 'monica and ross' 'rachel, chandler, and joey'
#  'the guys']
#
#
# friends_s03e10_ufs.txt
# ['girl' 'joey and monica' 'leader' 'rachel’s boss' 'sarah']
#
#
# friends_s03e11_ufs.txt
# ['cookie' "joey's grandmother" 'joey’s grandmother' 'joey’s sister'
#  'joey’s sisters' 'mark' 'mary-angela' 'mary-theresa' 'mr. kaplan'
#  'sister 1']
#
#
# friends_s03e12_ufs.txt
# ['bass singer' 'director' 'jeannine' 'julio' 'mark' 'quartet'
#  'the bass barber']
#
#
# friends_s03e13_ufs.txt
# Clerk: Eight o’clock is the cut-off and, aww, it’s 8:02.
#  eight o’clock is the cut-off and, aww, it’s 8:02.
# Monica: Oh, um, around 8:02. We ah, talked for a little while, and then um, we went out for an innocent burger.
#  oh, um, around 8:02. we ah, talked for a little while, and then um, we went out for an innocent burger.
# ['clerk' 'richard’s date' 'robert']
#
#
# friends_s03e14_ufs.txt
# ['commercial' 'ginger' 'lecturer' 'leslie' 'mark' 'monica, ross, and joey'
#  'phoebe and leslie' 'phoebe and monica' 'singer']
#
#
# friends_s03e15_ufs.txt
# Joey: Uh, 10:30.
#  uh, 10:30.
# Joey: 4:30.
#  4:30.
# ['chloe' 'issac' 'mark' 'mischa' 'phoebe and monica' 'sergei' 'sophie']
#
#
# friends_s03e16_ufs.txt
# Rachel: And y'know what, I’m gonna, I’m gonna go to bed now, but ah, on my way to work tomorrow morning, I’m gonna stop by around 8:30.
#  and y'know what, i’m gonna, i’m gonna go to bed now, but ah, on my way to work tomorrow morning, i’m gonna stop by around 8:30.
# Phoebe: Hi, it’s Phoebe. Listen someone’s gonna have to take my 9:00 with Mr. Rehack, ‘cause it’s like 9:15 now, and I’m not there.  No I-I'm in the middle of a huge relationship fight, so... Oh, that's all right. It's not mine.
#  hi, it’s phoebe. listen someone’s gonna have to take my 9:00 with mr. rehack, ‘cause it’s like 9:15 now, and i’m not there.  no i-i'm in the middle of a huge relationship fight, so... oh, that's all right. it's not mine.
# ['chloe' 'issac' 'jasmine' 'mark']
#
#
# friends_s03e17_ufs.txt
# ['chandler, phoebe, and joey' 'the girls']
#
#
# friends_s03e18_ufs.txt
# ['alice' 'employee' 'frank' 'hypnosis tape' 'pete' 'secretary']
#
#
# friends_s03e19_ufs.txt
# ['kate' 'mark' 'pete' 'spokeswoman']
#
#
# friends_s03e20_ufs.txt
# ['joanna' 'kate' 'lauren' 'sophie']
#
#
# friends_s03e21_ufs.txt
# ['anchorwoman' 'pete']
#
#
# friends_s03e22_ufs.txt
# Chandler: 7:15. Watch doesn’t work.
#  7:15. watch doesn’t work.
# ['cailin' 'chandler, phoebe, and rachel' 'estelle' 'hold voice' 'kate'
#  'lauren' 'pete' 'stage manager' 'tommy']
#
#
# friends_s03e23_ufs.txt
# ['dr. johnson' 'dr. rhodes' 'fireman' 'guru saj' 'jason' 'pete'
#  "pete's mom" 'vince']
#
#
# friends_s03e24_ufs.txt
# Doug: So, in conclusion, the lines all go up , so I’m happy. Great job team! Tomorrow at 8:30. Phil! Nice job. Stevens! Way to go! Joel-burg, you maniac! I love ya!  Bing! Good job, couldn’t have done it without ya.
#  so, in conclusion, the lines all go up , so i’m happy. great job team! tomorrow at 8:30. phil! nice job. stevens! way to go! joel-burg, you maniac! i love ya!  bing! good job, couldn’t have done it without ya.
# ['announcer' 'billy' 'billy crystal' 'bonnie' 'doug' 'hoshi' 'pete' 'phil'
#  'referee' 'robin' 'robin williams' 'stevens' 'the guys' 'tv announcer']
#
#
# friends_s03e25_ufs.txt
# ['bonnie' 'chandler, monica, and joey' 'phoebe sr' 'ross and bonnie'
#  'the girls' 'the guys']
#
#
# friends_s04e01_ufs.txt
# Ross: Okay. Wow, it’s-it’s 5:30 in the morning. So, I’d better get cracking on this baby.
#  okay. wow, it’s-it’s 5:30 in the morning. so, i’d better get cracking on this baby.
# Ross: It was 5:30 in the morning, and you had rambled on for 18 pages. Front and back!!  Oh-oh-oh, and by the way, Y-O-U-apostrophe-R-E means ‘you are,’ Y-O-U-R means ‘your!’
#  it was 5:30 in the morning, and you had rambled on for 18 pages. front and back!!  oh-oh-oh, and by the way, y-o-u-apostrophe-r-e means ‘you are,’ y-o-u-r means ‘your!’
# ['bonnie' 'chandler, monica, and joey' 'phoebe sr.'
#  'phoebe, ross, and rachel' 'rachel and bonnie']
#
#
# friends_s04e02_ufs.txt
# ['chandler, monica, joey, and rachel' 'chip' 'peter' 'tony']
#
#
# friends_s04e03_ufs.txt
# ['joanna' 'joey, rachel, and ross' 'monica, chandler, phoebe, and rachel'
#  'oven' 'sophie' 'the salesman']
#
#
# friends_s04e04_ufs.txt
# ['bank officer' 'dave' 'gym employee' 'interviewer' 'mr. simon'
#  'mr. treeger' 'mrs. potter' 'ms. lambert' 'rick']
#
#
# friends_s04e05_ufs.txt
# Chandler: Jeez, at 2:30 in the morning, I didn't expect to have to fight over the remote.
#  jeez, at 2:30 in the morning, i didn't expect to have to fight over the remote.
# Joey: It's 4:30.
#  it's 4:30.
# ['amanda' 'josh' 'kathy']
#
#
# friends_s04e06_ufs.txt
# ['cheryl' 'kathy' 'mrs. burkart']
#
#
# friends_s04e07_ufs.txt
# ['casey' 'kathy']
#
#
# friends_s04e08_ufs.txt
# ['doctor' 'dr. timothy burke' 'kathy' 'nurse' 'tim' 'voice']
#
#
# friends_s04e09_ufs.txt
# ['allesandro' 'joanna' 'mr. posner' 'mrs. lynch' 'sophie']
#
#
# friends_s04e10_ufs.txt
# ['a waiter' 'chandler, joey, and phoebe' 'drew' 'kitchen worker' 'mike'
#  'monica, rachel, and joey' 'the conductor' 'the waiter'
#  'the woman from poughkeepsie' 'woman on train']
#
#
# friends_s04e11_ufs.txt
# ['alice' 'chandler, monica and rachel' 'frank jr' 'frank jr.' 'kathy'
#  'kid' 'monica and rachel' 'phoebe sr.' 'rhonda' 'scientist #1'
#  'scientist #2' 'scott' 'tour guide #1' 'tour guide #2']
#
#
# friends_s04e12_ufs.txt
# ['alice' 'dr. zane' 'frank' 'frank and alice' 'the girls']
#
#
# friends_s04e13_ufs.txt
# ['joshua' 'kathy' "kathy's co-star" 'mr. waltham']
#
#
# friends_s04e14_ufs.txt
# Monica: It’s 9:30 in the morning!
#  it’s 9:30 in the morning!
# ['charlton heston' 'joshua' 'mr. waltham' 'the a.d' 'the cigarette guy'
#  'the cigarette smoking guy']
#
#
# friends_s04e15_ufs.txt
# Devon: So good then! We’ll see you at Riverside Park at 2:00! Cheers!
#  so good then! we’ll see you at riverside park at 2:00! cheers!
# ['devon' 'liam' 'mrs. chatracus' 'ticket counter attendant']
#
#
# friends_s04e16_ufs.txt
# ['joey and monica' 'joshua']
#
#
# friends_s04e17_ufs.txt
# ['alice' 'frank' 'frank jr.' 'mr. treeger' 'the doctor' 'ticket agent']
#
#
# friends_s04e18_ufs.txt
# Chandler: All right look, am I serious, okay? Tomorrow at 3:30 I am going down to the courthouse.
#  all right look, am i serious, okay? tomorrow at 3:30 i am going down to the courthouse.
# ['alice' 'joshua' 'mr. burgin' 'mrs. burgin']
#
#
# friends_s04e19_ufs.txt
# ['joey and the singing man' 'the singing man']
#
#
# friends_s04e20_ufs.txt
# Chandler: It’s 6:00.
#  it’s 6:00.
# ['joshua' 'marjorie' 'sleep clinic worker' 'the saleslady']
#
#
# friends_s04e21_ufs.txt
# ['chloe' 'monica, joey, and phoebe' 'rachel, monica, roy, and chip']
#
#
# friends_s04e22_ufs.txt
# ['jasmine' 'monica and rachel' 'the doctor' 'the guys' 'the stripper']
#
#
# friends_s04e23_ufs.txt
# ['crew man' 'dressmaker' 'drunk man' 'felicity' 'fergie' 'housekeeper'
#  'minister' 'mr. waltham' 'mrs. waltham' 'passenger' 'ross and monica'
#  'the vendor' 'ticket agent' 'waiter']
#
#
# friends_s05e01_ufs.txt
# ['gate agent' 'minister' 'mr. waltham' 'mrs. waltham']
#
#
# friends_s05e02_ufs.txt
# ['dave' 'the guys']
#
#
# friends_s05e03_ufs.txt
# ['alice' 'dan' 'delivery room nurse' 'dr. harad' 'dr. oberman' 'frank'
#  "joey's doctor" 'male nurse' 'nurse']
#
#
# friends_s05e04_ufs.txt
# ['ben' 'emeril' 'gary collins' 'pbs volunteer' 'stage director']
#
#
# friends_s05e05_ufs.txt
# ['chandler and phoebe' 'hotel clerk']
#
#
# friends_s05e06_ufs.txt
# ['chandler and monica' 'danny']
#
#
# friends_s05e07_ufs.txt
# ['danny' 'health inspector' 'larry' 'tom']
#
#
# friends_s05e08_ufs.txt
# ['big nosed rachel' 'french phoebe' 'past life phoebe' 'the doctor'
#  'the housekeeper' 'the paramedic']
#
#
# friends_s05e09_ufs.txt
# ['a female student' 'cynthia' 'dr. leedbetter' 'the teacher']
#
#
# friends_s05e10_ufs.txt
# Chandler: All right, it's 4:30. I guess my lunch break is over.  What are you guys going to do?
#  all right, it's 4:30. i guess my lunch break is over.  what are you guys going to do?
# ['bob' 'chandler and monica' 'danny' "danny's sister" 'estelle' 'krista'
#  'monica and ross' 'the man']
#
#
# friends_s05e11_ufs.txt
# ['ben' 'elizabeth' 'elizabeth hornswoggle' 'jay leno' 'joey and rachel']
#
#
# friends_s05e12_ufs.txt
# ['both' 'doug' 'dough' 'kara']
#
#
# friends_s05e13_ufs.txt
# ['frank sr.' 'the casting director' 'the pastor']
#
#
# friends_s05e14_ufs.txt
# ['[scene' 'dr. ledbetter']
#
#
# friends_s05e15_ufs.txt
# ['guest #1' 'guest #2' 'guest #3' 'katie' 'party guests' 'steve']
#
#
# friends_s05e16_ufs.txt
# ['chandler and monica' 'chandler and rachel' 'cop' 'dream joey'
#  'dream monica' 'gary' 'phoebe and joey' 'the salesman' 'the saleswoman'
#  'the smoking woman' 'voice']
#
#
# friends_s05e17_ufs.txt
# ['gary' "gary's radio" 'jen' 'mr. zelner' 'the hot girl' 'the little girl'
#  'the man' 'the old man' 'woman waiting']
#
#
# friends_s05e18_ufs.txt
# ['ben' 'kim' 'kyle' 'nancy' 'raymond' 'the casting director']
#
#
# friends_s05e19_ufs.txt
# Chandler: Made a few calls, pulled some strings, and they agreed to seat us at 11:30 if we both had the chicken and didn't get desert.
#  made a few calls, pulled some strings, and they agreed to seat us at 11:30 if we both had the chicken and didn't get desert.
# ['caitlin' 'delivery girl' 'grandma tribbiani']
#
#
# friends_s05e20_ufs.txt
# ['answering machine' 'gary']
#
#
# friends_s05e21_ufs.txt
# Ross: 2:17.
#  2:17.
# ['gary' 'phoebe and gary' 'woman no. 1' 'woman no. 2']
#
#
# friends_s05e22_ufs.txt
# ['dr. miller' 'stanley' 'the doctor' 'the grip' 'the husband']
#
#
# friends_s05e23_ufs.txt
# ['a casino boss' 'a drunken gambler' 'a tourist' 'blackjack dealer'
#  'chandler and monica' 'drunken gambler' "joey's hand twin"
#  'p.a. announcer' 'the attendant' 'the croupier' 'the flight attendant'
#  'the lurker' 'the security guard' 'the woman dealer']
#
#
# friends_s06e01_ufs.txt
# ['attendant' 'croupler' 'hitchhiker' 'the girls']
#
#
# friends_s06e02_ufs.txt
# ['karin' 'meg' 'russell' 'stephanie']
#
#
# friends_s06e03_ufs.txt
# ['the potential roommate']
#
#
# friends_s06e04_ufs.txt
# ['a crew member' 'a student' 'alex' 'casting director #1'
#  'casting director #2' 'casting director #3' 'estelle' 'russell'
#  'the professor']
#
#
# friends_s06e05_ufs.txt
# Ross: Okay, I got us a court date for tomorrow at 2:00 and I picked up all the forms. I’ll take care of everything.
#  okay, i got us a court date for tomorrow at 2:00 and i picked up all the forms. i’ll take care of everything.
# ['guy #1' 'guy #2' 'judge' 'passerby' 'the porsche owner']
#
#
# friends_s06e06_ufs.txt
# ['monica and rachel']
#
#
# friends_s06e07_ufs.txt
# ['janine']
#
#
# friends_s06e08_ufs.txt
# Joey: Or maybe, it’s because you’re hanging around here at 11:30 on a Wednesday.
#  or maybe, it’s because you’re hanging around here at 11:30 on a wednesday.
# ['chandler and monica' 'hillary' 'janine' 'kim' 'ralph lauren']
#
#
# friends_s06e09_ufs.txt
# ['janine' 'mr. and mrs. geller' 'the girls']
#
#
# friends_s06e10_ufs.txt
# ['director' 'girl' 'janine' 'joey’s head' 'monica and ross' 'tall guy']
#
#
# friends_s06e11_ufs.txt
# ['janine']
#
#
# friends_s06e12_ufs.txt
# Chandler: I think it’s great that you work here. You’re going to make a lot of money, and here’s your first tip. Don’t eat yellow snow. Ah ha ha, 2:15, coffeehouse.
#  i think it’s great that you work here. you’re going to make a lot of money, and here’s your first tip. don’t eat yellow snow. ah ha ha, 2:15, coffeehouse.
# ['customer' 'customers' 'monica and rachel' 'patron']
#
#
# friends_s06e13_ufs.txt
# ['a male customer' 'customer' 'jill']
#
#
# friends_s06e14_ufs.txt
# ['another man’s voice' 'buffay, the vampire layer' 'jill' 'man’s voice'
#  'same man’s voice' 'the fan' 'the vampire']
#
#
# friends_s06e15_ufs.txt
# ['arthur' 'ben' 'dr. drake remoray' 'dr. roger' 'dr. wesley'
#  'guy all the way in the back' 'hope' 'jack' "monica's boyfriend" 'nurse']
#
#
# friends_s06e17_ufs.txt
# ['carl' 'janice’s voice' "joey's look-a-like" 'receptionist' 'the doctor'
#  'the instructor']
#
#
# friends_s06e18_ufs.txt
# ['burt' 'dana' 'elizabeth' 'fireman #1' 'fireman #2' 'lydia' 'mel'
#  'the guys']
#
#
# friends_s06e19_ufs.txt
# ['eldad' 'elizabeth' 'patrick' 'professor feesen' 'sebastian']
#
#
# friends_s06e20_ufs.txt
# Chandler: Oh come on guys, it’s not like I moved to Europe! I just moved across the hall! And we would have you over all the time if it weren’t for Monica’s allergies. You’re right, I could never lie to you. She hates you. Should I get that? Hello? Uh no, Joey’s not here right now. Can I take a message? Yeah, okay so the audition has been moved from 5:00 to 2:30? Okay great. Bye.
#  oh come on guys, it’s not like i moved to europe! i just moved across the hall! and we would have you over all the time if it weren’t for monica’s allergies. you’re right, i could never lie to you. she hates you. should i get that? hello? uh no, joey’s not here right now. can i take a message? yeah, okay so the audition has been moved from 5:00 to 2:30? okay great. bye.
# Joey: Hello? What are you talking about? The audition’s not ‘til 5:00! Well, nobody told me! Who’d you talk to? Nevermind!
#  hello? what are you talking about? the audition’s not ‘til 5:00! well, nobody told me! who’d you talk to? nevermind!
# Ross: It was 5:30 in the morning, and you had rambled on for 18 pages. Front and back!!  Oh-oh-oh, and by the way, Y-O-U-apostrophe-R-E means ‘you are,’ Y-O-U-R means ‘your!’
#  it was 5:30 in the morning, and you had rambled on for 18 pages. front and back!!  oh-oh-oh, and by the way, y-o-u-apostrophe-r-e means ‘you are,’ y-o-u-r means ‘your!’
# Chandler: Joey? Got you a Joey Special, two pizzas! Joe?  Hello? Damnit! Hello? No, Joey’s not here right now, but I can take a message I think. He’s still got a chance for the part?! Oh, that’s great news! Well no obviously not for the actor who was mauled by his dog. Oh well, that’s great. I will give Joey the message. Thank you! Yes! Okay, Mac audition at 2:00. Allergy actor attacked. By dog not flowers.
#  joey? got you a joey special, two pizzas! joe?  hello? damnit! hello? no, joey’s not here right now, but i can take a message i think. he’s still got a chance for the part?! oh, that’s great news! well no obviously not for the actor who was mauled by his dog. oh well, that’s great. i will give joey the message. thank you! yes! okay, mac audition at 2:00. allergy actor attacked. by dog not flowers.
# ['dr. leedbetter' 'interviewer' 'lorraine' 'monica and rachel']
#
#
# friends_s06e21_ufs.txt
# ['c.h.e.e.s.e.' 'elizabeth' 'estelle' 'paul' 'phoebe and monica'
#  'the producer' 'wayne']
#
#
# friends_s06e22_ufs.txt
# ['elizabeth' 'female clerk' 'monica and rachel' 'paul' 'the dry cleaner'
#  'the museum official']
#
#
# friends_s06e23_ufs.txt
# ['customer' 'female jeweler' 'male jeweler' 'paul']
#
#
# friends_s06e24_ufs.txt
# ['elizabeth' 'emil alexander' 'first dorm guy' 'lisa' "maitre d'"
#  'mr. beaumont' 'mr. thompson' 'narrator' 'richard’s date' 'sarah'
#  'second dorm guy' 'the girls' 'waitress' 'zoe']
#
#
# friends_s07e01_ufs.txt
# []
#
#
# friends_s07e02_ufs.txt
# []
#
#
# friends_s07e03_ufs.txt
# []
#
#
# friends_s07e04_ufs.txt
# ['c.h.e.e.s.e' 'dr. stryker remoray' 'hilda' 'kathy' 'mac' 'nurse #1'
#  'nurse #2']
#
#
# friends_s07e05_ufs.txt
# ['blonde woman' 'hums while he pees' 'kyle' 'the photographer' 'whitney']
#
#
# friends_s07e06_ufs.txt
# Monica: Ohh, wow! That’s great! Oh wow! We really have to start planning! I have, I have a lot of really specific ideas! We should probably get together like four times per week. You can come over to my place. We’ll get together before work! What do you say, 6:30, my place? I’m so excited!
#  ohh, wow! that’s great! oh wow! we really have to start planning! i have, i have a lot of really specific ideas! we should probably get together like four times per week. you can come over to my place. we’ll get together before work! what do you say, 6:30, my place? i’m so excited!
# ['chef on tv' 'naked woman on tv']
#
#
# friends_s07e07_ufs.txt
# []
#
#
# friends_s07e08_ufs.txt
# ['joey, rachel, and phoebe']
#
#
# friends_s07e09_ufs.txt
# Tag: Yes, at 4:00.
#  yes, at 4:00.
# Chandler: 4:00 A.M.
#  4:00 a.m.
# ['ben' 'gary' 'mr. zelner' 'the knocker' 'the man' 'the woman']
#
#
# friends_s07e10_ufs.txt
# Chandler: Forty-five minutes? We have tickets to the Musicman at 8:00.
#  forty-five minutes? we have tickets to the musicman at 8:00.
# ['ben' "maitre d'" 'male guest' 'rachel and joey' 'salesman']
#
#
# friends_s07e11_ufs.txt
# Joey: I’ll see you at 8:00.
#  i’ll see you at 8:00.
# Chandler: Oh, what’s at 8:00?
#  oh, what’s at 8:00?
# Phoebe: Or! I should rush through dinner with Joey and I can meet David at 9:00!
#  or! i should rush through dinner with joey and i can meet david at 9:00!
# Chandler: Oh really? Uh, Monica said she had a date at 9:00.
#  oh really? uh, monica said she had a date at 9:00.
# ['aunt millie' 'david' 'frannie' 'the second guest' 'the waiter'
#  'the wedding guest' 'the woman']
#
#
# friends_s07e12_ufs.txt
# ['a disembodied voice' 'smoke detector' 'the fireman']
#
#
# friends_s07e13_ufs.txt
# ['earl' 'marge' 'supervisor' 'the "hey guy" guy']
#
#
# friends_s07e14_ufs.txt
# ['the man in the sportscar']
#
#
# friends_s07e15_ufs.txt
# Phoebe: Shhh! I’m on a call! Umm well yeah, you can pick it up tonight, say 8:30? At-at my apartment. It’s umm, it’s umm 5 Morton Street, Apartment 14, umm and then maybe y’know after we can grab a bite to eat or whatever. Okay, well okay I’ll see you then. Bye.
#  shhh! i’m on a call! umm well yeah, you can pick it up tonight, say 8:30? at-at my apartment. it’s umm, it’s umm 5 morton street, apartment 14, umm and then maybe y’know after we can grab a bite to eat or whatever. okay, well okay i’ll see you then. bye.
# ['cecilia' 'dina' 'fredrick' 'jessica lockhart' 'monica and chandler'
#  'the writer' 'tom']
#
#
# friends_s07e16_ufs.txt
# Chandler: Well I was… I wasn't exactly expecting company after… 9:15.
#  well i was… i wasn't exactly expecting company after… 9:15.
# ['ben' 'fat joey' 'monica and chandler']
#
#
# friends_s07e17_ufs.txt
# Ross: We have 8:00 reservations at Grammercy Bistero.
#  we have 8:00 reservations at grammercy bistero.
# ['a woman' 'kristen' 'megan' 'the woman' 'waiter']
#
#
# friends_s07e18_ufs.txt
# Rachel: Honey, we have to go. Our reservations are at 8:00.
#  honey, we have to go. our reservations are at 8:00.
# Phoebe: …in Reservations at 8:00 by Neil Simon. Thank-thank you Neil. Thank you for the words.
#  …in reservations at 8:00 by neil simon. thank-thank you neil. thank you for the words.
# ['announcer' 'cameraman' 'jessica ashley' 'lewis' 'morse' 'the cute guy'
#  'the presenter' 'waitress']
#
#
# friends_s07e19_ufs.txt
# ['cassie' 'estelle' 'the casting director' 'the other woman']
#
#
# friends_s07e20_ufs.txt
# Joey: Listen, I know the invitation says 6:00, but does that mean that you want people to get there at 6:00, or the show is gonna start right at 6:00?
#  listen, i know the invitation says 6:00, but does that mean that you want people to get there at 6:00, or the show is gonna start right at 6:00?
# []
#
#
# friends_s07e21_ufs.txt
# []
#
#
# friends_s07e22_ufs.txt
# ['announcer' 'helena' 'policeman' 'the chorus' 'waiter in drag' 'waitress']
#
#
# friends_s07e23_ufs.txt
# ['the assistant director' 'the priest']
